# %% [markdown]
# # Colab-GitHub Bridge Demo
#
# This notebook demonstrates the capabilities of the Colab-GitHub Bridge CLI.

# %% [markdown]
# ## Setup
#
# First, run the bootstrap cell from `bootstrap_colab.ipynb`

# %%
# Install and import
# !pip install gitpython requests pyyaml click -q
# !git clone https://github.com/sylvanaxe14/colab-github-bridge-cli.git /tmp/bridge-cli

import sys
sys.path.insert(0, '/tmp/bridge-cli')

from cli.colab_integration import (
    clone_repo,
    commit_changes,
    push_changes,
    get_repo_status,
)

print("✓ Ready to use!")

# %% [markdown]
# ## Demo: Working with a Repository
#
# This demo shows how to:
# 1. Clone a repository
# 2. Make modifications
# 3. Commit changes
# 4. Push back to GitHub

# %%
# Step 1: Clone a test repository
print("Step 1: Cloning repository...")
# Uncomment to use:
# repo = clone_repo("https://github.com/your-username/test-repo.git", "test_repo")

# %%
# Step 2: Check repository status
# status = get_repo_status("test_repo")
# print("Repository Status:")
# for key, value in status.items():
#     print(f"  {key}: {value}")

# %%
# Step 3: Create or modify files
# Example: Create a new analysis file
# with open("test_repo/analysis.py", "w") as f:
#     f.write("""
# def analyze_data():
#     print("Analysis complete")
# 
# if __name__ == "__main__":
#     analyze_data()
# """)

# %%
# Step 4: Commit changes
# commit_changes("test_repo", "Added analysis script from Colab")
# print("✓ Changes committed")

# %%
# Step 5: Push to GitHub
# Note: You'll need to authenticate first (PAT or SSH key)
# push_changes("test_repo")
# print("✓ Changes pushed to GitHub!")

# %% [markdown]
# ## Next Steps
#
# - Configure authentication (PAT or SSH)
# - Set up branch protections in GitHub
# - Create pull requests from your analysis
# - Automate workflows with GitHub Actions
