# %% [markdown]
# # Colab-GitHub Bridge Bootstrap
#
# This notebook bootstraps your Colab environment for GitHub integration.
#
# Run this cell to get started:

# %%
# Install dependencies
# !pip install gitpython requests pyyaml click -q

# Clone the bridge CLI repo
# !git clone https://github.com/sylvanaxe14/colab-github-bridge-cli.git /tmp/bridge-cli
import sys
sys.path.insert(0, '/tmp/bridge-cli')

# Import helpers
from cli.colab_integration import (
    setup_colab_environment,
    clone_repo,
    commit_changes,
    push_changes,
    get_current_branch,
    get_repo_status,
)

# Initialize environment
setup_colab_environment()

print("\n✓ Bootstrap complete! You can now use the helpers below.")
print("\nAvailable functions:")
print("  - clone_repo(url, path)")
print("  - commit_changes(path, message)")
print("  - push_changes(path, remote, branch)")
print("  - get_current_branch(path)")
print("  - get_repo_status(path)")

# %% [markdown]
# ## Example Usage
#
# ### Clone a Repository

# %%
# Example: Clone your repository
# repo = clone_repo("https://github.com/your-username/your-repo.git")

# %% [markdown]
# ### Make Changes and Commit

# %%
# Example: Make changes to files in the repo
# Then commit them:
# commit_changes("your-repo", "Added analysis results")

# %% [markdown]
# ### Push Changes to GitHub

# %%
# Example: Push your changes
# push_changes("your-repo")

# %% [markdown]
# ### Check Repository Status

# %%
# Example: Check current status
# status = get_repo_status("your-repo")
# print(status)
